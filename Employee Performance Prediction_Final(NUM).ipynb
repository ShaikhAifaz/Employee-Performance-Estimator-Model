# %% [markdown]
# # 1. Import Libraries and Dataset

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
Employee = pd.read_excel(r"D:/4] 360DigiTMG Projects/1] Data Science/Project No.2/Dataset Codes/Final_EP_Dataset(Num).xlsx")
Employee
# Out:
#       Employee_ID  Age  years_of_experience  Gender Marital Status  \
# 0            3556   57                 32.0    Male         Single
# 1            6484   46                 23.0  Female        Married
# 2            6037   46                 23.0    Male         Single
# 3            5199   36                 12.0    Male       Divorced
# 4            5224   57                 32.0    Male        Married
# ...           ...  ...                  ...     ...            ...
# 5495         3042   37                 12.0  Female       Divorced
# 5496         6418   47                 23.0    Male       Divorced
# 5497         2015   45                 21.0    Male         Single
# 5498         5620   30                  5.0    Male        Married
# 5499         5852   59                 35.0  Female       Divorced
#
#                                 Department                     Job_role  \
# 0                         Customer_service  Customer_service_supervisor
# ...

# %%
Employee.shape
# Out:
# (5500, 31)

# %%
Employee.head()
# Out:
#    Employee_ID  Age  years_of_experience  Gender Marital Status  \
# 0         3556   57                 32.0    Male         Single
# 1         6484   46                 23.0  Female        Married
# 2         6037   46                 23.0    Male         Single
# 3         5199   36                 12.0    Male       Divorced
# 4         5224   57                 32.0    Male        Married
#
#                  Department                     Job_role  Education_level  \
# 0          Customer_service  Customer_service_supervisor                3
# 1  Research_and_Development                 R&D_engineer                3
# 2                     Sales              Sales_Executive                3
# 3   Supply_chain_management         Supply_chain_manager                3
# 4            Human_Resource     Training_and_Development                3
#
#    Work_Environment_Satisfaction_Level  JobInvolvement  ...  Working_Status  \
# ...

# %%
Employee.tail()
# Out:
#       Employee_ID  Age  years_of_experience  Gender Marital Status  \
# 5495         3042   37                 12.0  Female       Divorced
# 5496         6418   47                 23.0    Male       Divorced
# 5497         2015   45                 21.0    Male         Single
# 5498         5620   30                  5.0    Male        Married
# 5499         5852   59                 35.0  Female       Divorced
#
#                                 Department                   Job_role  \
# 5495                      Customer_service  Customer_support_engineer
# 5496  Computers_and_information_technology   Senior_software_engineer
# 5497                            Management          Marketing_Manager
# 5498                               Finance                  Treasurer
# 5499                               Finance            Finance_analyst
#
#       Education_level  Work_Environment_Satisfaction_Level  JobInvolvement  \
# ...

# %%
Employee.columns
# Out:
# Index(['Employee_ID', 'Age', 'years_of_experience', 'Gender', 'Marital Status',
#        'Department', 'Job_role', 'Education_level',
#        'Work_Environment_Satisfaction_Level', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'Annual_Income_in_lacs', 'RelationshipSatisfaction',
#        'Working_hrs_per_day', 'Training_Time_in_months', 'Work_Life_Balance',
#        'Behaviourial_Competence', 'On_Time_Delivery',
#        'Ticket_Solving_Management', 'Project_Completion', 'Working_Status',
#        'Willing_to_work_from_office', 'Psycho_social_indicators', 'Feedback',
#        'Over_time', 'Percentage_of_Attendence', 'Effected_with_corona',
#        'Percent_salary_hike', 'Net_connectivity', 'Performance_Rating'],
#       dtype='object')

# %%
Employee.describe()
# Out:
#        Employee_ID          Age  years_of_experience  Education_level  \
# count  5500.000000  5500.000000          5499.000000      5500.000000
# mean   3749.500000    40.198000            15.801964         3.535091
# std    1587.857571    11.821914            10.939609         0.972455
# min    1000.000000    20.000000             1.000000         1.000000
# 25%    2374.750000    30.000000             5.000000         3.000000
# 50%    3749.500000    40.000000            16.000000         3.000000
# 75%    5124.250000    50.000000            25.000000         4.000000
# max    6499.000000    60.000000            38.000000         5.000000
#
#        Work_Environment_Satisfaction_Level  JobInvolvement     JobLevel  \
# count                          5500.000000     5498.000000  5499.000000
# mean                              2.756364        2.831575     2.957811
# std                               0.970892        0.958863     1.383279
# ...

# %%
Employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 31 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Employee_ID                          5500 non-null   int64
#  1   Age                                  5500 non-null   int64
#  2   years_of_experience                  5499 non-null   float64
#  3   Gender                               5500 non-null   object
#  4   Marital Status                       5500 non-null   object
#  5   Department                           5500 non-null   object
#  6   Job_role                             5500 non-null   object
#  7   Education_level                      5500 non-null   int64
#  8   Work_Environment_Satisfaction_Level  5500 non-null   int64
#  9   JobInvolvement                       5498 non-null   float64
#  10  JobLevel                             5499 non-null   float64
# ...

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 2.1 Null values in the dataset

# %%
Employee.isna().sum()
# Out:
# Employee_ID                            0
# Age                                    0
# years_of_experience                    1
# Gender                                 0
# Marital Status                         0
# Department                             0
# Job_role                               0
# Education_level                        0
# Work_Environment_Satisfaction_Level    0
# JobInvolvement                         2
# JobLevel                               1
# JobSatisfaction                        1
# Annual_Income_in_lacs                  1
# RelationshipSatisfaction               3
# Working_hrs_per_day                    3
# Training_Time_in_months                1
# Work_Life_Balance                      0
# Behaviourial_Competence                1
# On_Time_Delivery                       4
# Ticket_Solving_Management              0
# Project_Completion                     0
# Working_Status                         0
# Willing_to_work_from_office            2
# ...

# %% [markdown]
# Null Values present in the dataset

# %%
# Mean Imputer
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
Employee["years_of_experience"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["years_of_experience"]]))
Employee["JobInvolvement"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["JobInvolvement"]]))
Employee["JobLevel"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["JobLevel"]]))
Employee["JobSatisfaction"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["JobSatisfaction"]]))
Employee["RelationshipSatisfaction"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["RelationshipSatisfaction"]]))
Employee["Working_hrs_per_day"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["Working_hrs_per_day"]]))
Employee["Training_Time_in_months"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["Training_Time_in_months"]]))
Employee["Behaviourial_Competence"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["Behaviourial_Competence"]]))
Employee["On_Time_Delivery"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["On_Time_Delivery"]]))
Employee["Willing_to_work_from_office"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["Willing_to_work_from_office"]]))
Employee["Feedback"] = pd.DataFrame(mean_imputer.fit_transform(Employee[["Feedback"]]))

# %%
# Median Imputer
median_imputer = SimpleImputer(missing_values=np.nan, strategy='median')
Employee["Annual_Income_in_lacs"] = pd.DataFrame(median_imputer.fit_transform(Employee[["Annual_Income_in_lacs"]]))
Employee["Percentage_of_Attendence"] = pd.DataFrame(median_imputer.fit_transform(Employee[["Percentage_of_Attendence"]]))
Employee["Percent_salary_hike"] = pd.DataFrame(median_imputer.fit_transform(Employee[["Percent_salary_hike"]]))

# %%
Employee.isna().sum()
# Out:
# Employee_ID                            0
# Age                                    0
# years_of_experience                    0
# Gender                                 0
# Marital Status                         0
# Department                             0
# Job_role                               0
# Education_level                        0
# Work_Environment_Satisfaction_Level    0
# JobInvolvement                         0
# JobLevel                               0
# JobSatisfaction                        0
# Annual_Income_in_lacs                  0
# RelationshipSatisfaction               0
# Working_hrs_per_day                    0
# Training_Time_in_months                0
# Work_Life_Balance                      0
# Behaviourial_Competence                0
# On_Time_Delivery                       0
# Ticket_Solving_Management              0
# Project_Completion                     0
# Working_Status                         0
# Willing_to_work_from_office            0
# ...

# %% [markdown]
# There is No Null values in the datasets

# %% [markdown]
# ### 2.2 Duplicate values

# %%
Employee.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is No Duplicate values

# %% [markdown]
# ### 2.3 An Outliers in the dataset

# %%
fig=plt.figure(figsize=(50,40))
sns.boxplot(data= Employee)
plt.show()

# %% [markdown]
# There is an outlier present in "Education_level", "Annual_Income_in_lacs", "Project_Completion" Columns

# %%
sns.boxplot(Employee["Education_level"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education_level'>

# %%
# Detection of outliers (find limits for salary based on IQR)
IQR = Employee['Education_level'].quantile(0.75) - Employee['Education_level'].quantile(0.25)
lower_limit = Employee['Education_level'].quantile(0.25) - (IQR * 1.5)
upper_limit = Employee['Education_level'].quantile(0.75) + (IQR * 1.5)

############### 2.Replace ###############
# Now let's replace the outliers by the maximum and minimum limit
Employee['Education_level'] = pd.DataFrame(np.where(Employee['Education_level'] > upper_limit, upper_limit, np.where(Employee['Education_level'] < lower_limit, lower_limit, Employee['Education_level'])))
sns.boxplot(Employee.Education_level)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education_level'>

# %%
sns.boxplot(Employee["Annual_Income_in_lacs"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual_Income_in_lacs'>

# %%
# Detection of outliers (find limits for salary based on IQR)
IQR = Employee['Annual_Income_in_lacs'].quantile(0.75) - Employee['Annual_Income_in_lacs'].quantile(0.25)
lower_limit = Employee['Annual_Income_in_lacs'].quantile(0.25) - (IQR * 1.5)
upper_limit = Employee['Annual_Income_in_lacs'].quantile(0.75) + (IQR * 1.5)

############### 2.Replace ###############
# Now let's replace the outliers by the maximum and minimum limit
Employee['Annual_Income_in_lacs'] = pd.DataFrame(np.where(Employee['Annual_Income_in_lacs'] > upper_limit, upper_limit, np.where(Employee['Annual_Income_in_lacs'] < lower_limit, lower_limit, Employee['Annual_Income_in_lacs'])))
sns.boxplot(Employee.Education_level)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education_level'>

# %%
sns.boxplot(Employee["Project_Completion"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Project_Completion'>

# %%
# Detection of outliers (find limits for salary based on IQR)
IQR = Employee['Project_Completion'].quantile(0.75) - Employee['Project_Completion'].quantile(0.25)
lower_limit = Employee['Project_Completion'].quantile(0.25) - (IQR * 1.5)
upper_limit = Employee['Project_Completion'].quantile(0.75) + (IQR * 1.5)

############### 2.Replace ###############
# Now let's replace the outliers by the maximum and minimum limit
Employee['Project_Completion'] = pd.DataFrame(np.where(Employee['Project_Completion'] > upper_limit, upper_limit, np.where(Employee['Project_Completion'] < lower_limit, lower_limit, Employee['Project_Completion'])))
sns.boxplot(Employee.Education_level)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Education_level'>

# %%
fig=plt.figure(figsize=(55,40))
sns.boxplot(data= Employee)
plt.show()

# %% [markdown]
# Outliers removed from the dataset

# %% [markdown]
# # 3. Data Visualization

# %% [markdown]
# ### 3.1 Count plots

# %%
plt.figure(figsize=(20, 4))
sns.countplot(x=Employee['Department'],color="aqua")
Employee["Department"].value_counts()
# Out:
# Research_and_Development                529
# Finance                                 523
# Sales                                   520
# Customer_service                        518
# Management                              515
# Quality_assurance                       508
# Supply_chain_management                 488
# Computers_and_information_technology    486
# Production                              485
# Marketing                               466
# Human_Resource                          462
# Name: Department, dtype: int64

# %%
sns.countplot(Employee.Working_Status)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Working_Status', ylabel='count'>

# %%
sns.countplot(Employee.Over_time)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Over_time', ylabel='count'>

# %%
sns.countplot(Employee.Effected_with_corona)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Effected_with_corona', ylabel='count'>

# %%
sns.countplot(Employee.Performance_Rating)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Performance_Rating', ylabel='count'>

# %% [markdown]
# ### 3.2 Pairplot

# %%
sns.pairplot(Employee)

# %% [markdown]
# ### 3.3 Histogram

# %%
plt.hist(Employee.Age)
# Out:
# (array([506., 537., 527., 553., 532., 544., 534., 531., 523., 713.]),
#  array([20., 24., 28., 32., 36., 40., 44., 48., 52., 56., 60.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Employee.years_of_experience)
# Out:
# (array([1227.,  700.,  452.,  335.,  536.,  517.,  597.,  470.,  471.,
#          195.]),
#  array([ 1. ,  4.7,  8.4, 12.1, 15.8, 19.5, 23.2, 26.9, 30.6, 34.3, 38. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Employee.Annual_Income_in_lacs)
# Out:
# (array([1894.,  402.,  637.,  875.,  831.,  854.,    0.,    0.,    0.,
#            7.]),
#  array([ 5.  ,  9.55, 14.1 , 18.65, 23.2 , 27.75, 32.3 , 36.85, 41.4 ,
#         45.95, 50.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Employee.Project_Completion)
# Out:
# (array([8.050e+02, 6.310e+02, 7.460e+02, 1.420e+02, 7.570e+02, 2.414e+03,
#         0.000e+00, 1.000e+00, 1.000e+00, 3.000e+00]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. , 15.4, 17.8, 20.2, 22.6, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Employee.Percentage_of_Attendence)
# Out:
# (array([ 182.,  291.,  211.,  276.,  456.,  614.,  609.,  746.,  883.,
#         1232.]),
#  array([ 34. ,  40.6,  47.2,  53.8,  60.4,  67. ,  73.6,  80.2,  86.8,
#          93.4, 100. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 3.4 Correlation Coefficient Plot

# %%
corelation = Employee.corr()

# %%
plt.figure(figsize=(20,14))
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. Data Preprocessing

# %% [markdown]
# ### 4.1 Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
Employee["Gender"]= labelencoder.fit_transform(Employee["Gender"])
Employee["Marital Status"]= labelencoder.fit_transform(Employee["Marital Status"])
Employee["Department"]= labelencoder.fit_transform(Employee["Department"])
Employee["Job_role"]= labelencoder.fit_transform(Employee["Job_role"])
Employee["Working_Status"]= labelencoder.fit_transform(Employee["Working_Status"])
Employee
# Out:
#       Employee_ID  Age  years_of_experience  Gender  Marital Status  \
# 0            3556   57                 32.0       1               2
# 1            6484   46                 23.0       0               1
# 2            6037   46                 23.0       1               2
# 3            5199   36                 12.0       1               0
# 4            5224   57                 32.0       1               1
# ...           ...  ...                  ...     ...             ...
# 5495         3042   37                 12.0       0               0
# 5496         6418   47                 23.0       1               0
# 5497         2015   45                 21.0       1               2
# 5498         5620   30                  5.0       1               1
# 5499         5852   59                 35.0       0               0
#
#       Department  Job_role  Education_level  \
# 0              1        14              3.0
# 1              8        46              3.0
# ...

# %% [markdown]
# ### 4.2 Type Casting

# %%
Employee.dtypes
# Out:
# Employee_ID                              int64
# Age                                      int64
# years_of_experience                    float64
# Gender                                   int32
# Marital Status                           int32
# Department                               int32
# Job_role                                 int32
# Education_level                        float64
# Work_Environment_Satisfaction_Level      int64
# JobInvolvement                         float64
# JobLevel                               float64
# JobSatisfaction                        float64
# Annual_Income_in_lacs                  float64
# RelationshipSatisfaction               float64
# Working_hrs_per_day                    float64
# Training_Time_in_months                float64
# Work_Life_Balance                        int64
# Behaviourial_Competence                float64
# On_Time_Delivery                       float64
# Ticket_Solving_Management                int64
# ...

# %%
Employee.years_of_experience = Employee.years_of_experience.astype('int64')
Employee.Education_level = Employee.Education_level.astype('int64')
Employee.JobInvolvement = Employee.JobInvolvement.astype('int64')
Employee.JobLevel = Employee.JobLevel.astype('int64')
Employee.JobSatisfaction = Employee.JobSatisfaction.astype('int64')
Employee.Annual_Income_in_lacs = Employee.Annual_Income_in_lacs.astype('int64')
Employee.RelationshipSatisfaction = Employee.RelationshipSatisfaction.astype('int64')
Employee.Working_hrs_per_day = Employee.Working_hrs_per_day.astype('int64')
Employee.Training_Time_in_months = Employee.Training_Time_in_months.astype('int64')
Employee.Behaviourial_Competence = Employee.Behaviourial_Competence.astype('int64')
Employee.On_Time_Delivery = Employee.On_Time_Delivery.astype('int64')
Employee.Project_Completion = Employee.Project_Completion.astype('int64')
Employee.Willing_to_work_from_office = Employee.Willing_to_work_from_office.astype('int64')
Employee.Percentage_of_Attendence = Employee.Percentage_of_Attendence.astype('int64')
Employee.Percent_salary_hike = Employee.Percent_salary_hike.astype('int64')
Employee.Feedback = Employee.Feedback.astype('int64')
Employee.dtypes
# Out:
# Employee_ID                            int64
# Age                                    int64
# years_of_experience                    int64
# Gender                                 int32
# Marital Status                         int32
# Department                             int32
# Job_role                               int32
# Education_level                        int64
# Work_Environment_Satisfaction_Level    int64
# JobInvolvement                         int64
# JobLevel                               int64
# JobSatisfaction                        int64
# Annual_Income_in_lacs                  int64
# RelationshipSatisfaction               int64
# Working_hrs_per_day                    int64
# Training_Time_in_months                int64
# Work_Life_Balance                      int64
# Behaviourial_Competence                int64
# On_Time_Delivery                       int64
# Ticket_Solving_Management              int64
# Project_Completion                     int64
# ...

# %% [markdown]
# ### 4.3 Varience, Skewness and kurtosis

# %%
Employee.var() # variance of numeric variables
# Out:
# Employee_ID                            2.521292e+06
# Age                                    1.397577e+02
# years_of_experience                    1.196534e+02
# Gender                                 2.500137e-01
# Marital Status                         4.077434e-01
# Department                             1.005715e+01
# Job_role                               3.481501e+02
# Education_level                        9.456678e-01
# Work_Environment_Satisfaction_Level    9.426309e-01
# JobInvolvement                         9.193346e-01
# JobLevel                               1.913280e+00
# JobSatisfaction                        9.552037e-01
# Annual_Income_in_lacs                  8.037344e+01
# RelationshipSatisfaction               1.248407e+00
# Working_hrs_per_day                    6.690212e-01
# Training_Time_in_months                2.931656e+00
# Work_Life_Balance                      1.009788e+00
# Behaviourial_Competence                2.287463e+00
# ...

# %%
Employee.skew()
# Out:
# Employee_ID                            0.000000
# Age                                    0.005753
# years_of_experience                    0.157675
# Gender                                 0.022553
# Marital Status                        -0.495549
# Department                            -0.011854
# Job_role                              -0.107196
# Education_level                       -0.401458
# Work_Environment_Satisfaction_Level   -0.500470
# JobInvolvement                        -0.565604
# JobLevel                               0.071802
# JobSatisfaction                       -0.572015
# Annual_Income_in_lacs                  0.104183
# RelationshipSatisfaction               0.010297
# Working_hrs_per_day                    0.005689
# Training_Time_in_months               -0.009548
# Work_Life_Balance                     -0.309301
# Behaviourial_Competence               -0.551665
# On_Time_Delivery                      -0.783745
# Ticket_Solving_Management             -0.694695
# ...

# %%
Employee.kurt()
# Out:
# Employee_ID                           -1.200000
# Age                                   -1.206851
# years_of_experience                   -1.314583
# Gender                                -2.000219
# Marital Status                        -0.672078
# Department                            -1.244512
# Job_role                              -1.292611
# Education_level                        0.246148
# Work_Environment_Satisfaction_Level   -0.689976
# JobInvolvement                        -0.569714
# JobLevel                              -1.196443
# JobSatisfaction                       -0.632578
# Annual_Income_in_lacs                 -1.370987
# RelationshipSatisfaction              -1.358231
# Working_hrs_per_day                   -1.505263
# Training_Time_in_months               -1.288372
# Work_Life_Balance                     -0.976419
# Behaviourial_Competence               -0.614220
# On_Time_Delivery                      -0.866416
# Ticket_Solving_Management             -0.846256
# ...

# %% [markdown]
# # 5. Model Building

# %% [markdown]
# ### 5.1 Dropping Unnecessary Columns

# %%
Employee = Employee.drop(["Employee_ID"],axis=1)
Employee
# Out:
#       Age  years_of_experience  Gender  Marital Status  Department  Job_role  \
# 0      57                   32       1               2           1        14
# 1      46                   23       0               1           8        46
# 2      46                   23       1               2           9        50
# 3      36                   12       1               0          10        57
# 4      57                   32       1               1           3        60
# ...   ...                  ...     ...             ...         ...       ...
# 5495   37                   12       0               0           1        15
# 5496   47                   23       1               0           0        53
# 5497   45                   21       1               2           4        29
# 5498   30                    5       1               1           2        61
# 5499   59                   35       0               0           2        21
#
# ...

# %% [markdown]
# ### 5.2 Normalization

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
Employee1 = norm_func(Employee)

# %% [markdown]
# ### 5.3 Predictors and Target

# %%
X = Employee1.drop(["Performance_Rating"],axis=1)
X
# Out:
#         Age  years_of_experience  Gender  Marital Status  Department  \
# 0     0.925             0.837838     1.0             1.0         0.1
# 1     0.650             0.594595     0.0             0.5         0.8
# 2     0.650             0.594595     1.0             1.0         0.9
# 3     0.400             0.297297     1.0             0.0         1.0
# 4     0.925             0.837838     1.0             0.5         0.3
# ...     ...                  ...     ...             ...         ...
# 5495  0.425             0.297297     0.0             0.0         0.1
# 5496  0.675             0.594595     1.0             0.0         0.0
# 5497  0.625             0.540541     1.0             1.0         0.4
# 5498  0.250             0.108108     1.0             0.5         0.2
# 5499  0.975             0.918919     0.0             0.0         0.2
#
#       Job_role  Education_level  Work_Environment_Satisfaction_Level  \
# ...

# %%
Y = Employee["Performance_Rating"]
Y
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 5495    4
# 5496    3
# 5497    4
# 5498    4
# 5499    4
# Name: Performance_Rating, Length: 5500, dtype: int64

# %% [markdown]
# ### 5.4 Splitting Dataset into Training and Testing

# %%
# splitting the data into testing and training data.

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %% [markdown]
# # Model 01 : KNN

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 21)
knn.fit(X_train, Y_train)

pred = knn.predict(X_test)
pred

# Evaluate the model
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, pred))
pd.crosstab(Y_test, pred, rownames = ['Actual'], colnames= ['Predictions']) 


# error on train data
pred_train = knn.predict(X_train)
print(accuracy_score(Y_train, pred_train))
pd.crosstab(Y_train, pred_train, rownames=['Actual'], colnames = ['Predictions'])
# Out:
# 0.88
# 0.9095757575757576
# Predictions    1     2    3     4
# Actual
# 1            823     0    0     0
# 2              0  1057   73     0
# 3              0    20  537   260
# 4              0     0   20  1335

# %% [markdown]
# # Model 02 : Logistic Regression

# %%
#logistic  regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

lr = LogisticRegression()

lr.fit(X_train, Y_train)

Y_pred = lr.predict(X_test)

lr_train_acc = accuracy_score(Y_train, lr.predict(X_train))
lr_test_acc = accuracy_score(Y_test, Y_pred)

print(f"Training Accuracy of Logistic Regression Model is {lr_train_acc}")
print(f"Test Accuracy of Logistic Regression Model is {lr_test_acc}")
# Out:
# Training Accuracy of Logistic Regression Model is 0.9970909090909091
# Test Accuracy of Logistic Regression Model is 0.9978181818181818
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Model 03 : Decision Tree

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
#decision tree
dtc = DecisionTreeClassifier()
dtc.fit(X_train, Y_train)

Y_pred = dtc.predict(X_test)

dtc_train_acc = accuracy_score(Y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(Y_test, Y_pred)

print(f"Training Accuracy of Decision Tree Model is {dtc_train_acc}")
print(f"Test Accuracy of Decision Tree Model is {dtc_test_acc}")
# Out:
# Training Accuracy of Decision Tree Model is 1.0
# Test Accuracy of Decision Tree Model is 0.9963636363636363

# %% [markdown]
# # Model 04 : Random Forest

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion = 'gini', max_depth = 8, max_features = 'sqrt', min_samples_leaf = 4, min_samples_split = 5, n_estimators = 150)
rand_clf.fit(X_train, Y_train)

Y_pred = rand_clf.predict(X_test)

rand_clf_train_acc = accuracy_score(Y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(Y_test, Y_pred)

print(f"Training Accuracy of Random Forest Model is {rand_clf_train_acc}")
print(f"Test Accuracy of Random Forest Model is {rand_clf_test_acc}")
# Out:
# Training Accuracy of Random Forest Model is 0.9992727272727273
# Test Accuracy of Random Forest Model is 0.9985454545454545

# %% [markdown]
# # Model 05 : XGBoost

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(booster = 'gblinear', learning_rate = .1, max_depth = 3, n_estimators = 750)
xgb.fit(X_train, Y_train)

Y_pred = xgb.predict(X_test)

xgb_train_acc = accuracy_score(Y_train, xgb.predict(X_train))
xgb_test_acc = accuracy_score(Y_test, Y_pred)

print(f"Training Accuracy of XGB Model is {xgb_train_acc}")
print(f"Test Accuracy of XGB Model is {xgb_test_acc}")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:15:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ...

# %% [markdown]
# # Testing Accuracies

# %%
models = [ 'KNN', 'logistic  regression', 'Decision Tree', 'Random Forest', 'XgBoost'] 
scores = [ accuracy_score(Y_test, pred), lr_test_acc, dtc_test_acc, rand_clf_test_acc, xgb_test_acc]

models_test = pd.DataFrame({'Model' : models, 'Score' : scores})


models_test.sort_values(by = 'Score', ascending = False)
# Out:
#                   Model     Score
# 3         Random Forest  0.998545
# 1  logistic  regression  0.997818
# 2         Decision Tree  0.996364
# 4               XgBoost  0.966545
# 0                   KNN  0.880000

# %%
plt.figure(figsize = (10, 8))

sns.barplot(x = 'Model', y = 'Score', data = models_test)
plt.show()

# %% [markdown]
# # Training Accuracies

# %%
models = [ 'KNN', 'logistic  regression', 'Decision Tree', 'Random Forest', 'XgBoost'] 
scores = [  accuracy_score(Y_train, pred_train), lr_train_acc, dtc_train_acc, rand_clf_train_acc, xgb_train_acc]

models_train = pd.DataFrame({'Model' : models, 'Score' : scores})


models_train.sort_values(by = 'Score', ascending = False)
# Out:
#                   Model     Score
# 2         Decision Tree  1.000000
# 3         Random Forest  0.999273
# 1  logistic  regression  0.997091
# 4               XgBoost  0.969697
# 0                   KNN  0.909576

# %%
plt.figure(figsize = (10, 8))

sns.barplot(x = 'Model', y = 'Score', data = models_train)
plt.show()
